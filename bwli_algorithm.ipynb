# %%
import time
from collections import defaultdict
import logging

import h5py
import numpy as np
from ase import Atoms
from ase.io import read, write
from dscribe.descriptors import SOAP
from dscribe.kernels import AverageKernel
from joblib import Parallel, delayed

# %%
def compute_soap_descriptors(structures, njobs, species, r_cut, n_max, l_max):
    """
    Function: Compute SOAP descriptors for a list of structures
    Input:
        SOAP inputs
    Output:
        List of SOAP descriptors in numpy.ndarray format
    """
    start_time = time.time()
    soap = SOAP(
        species=species,
        r_cut=r_cut,
        n_max=n_max,
        l_max=l_max
    )
    soap_descriptors = soap.create(structures, n_jobs=njobs)
    end_time = time.time()
    logging.info(f"SOAP descriptors computed in {end_time - start_time:.2f} seconds")

    # 由于此处调用本函数计算时，structures 中的结构默认是化学式相同的，因此返回的是 np.ndarray
    # 需要返回 list 类型，其中元素为 np.ndarray
    if type(soap_descriptors) == np.ndarray:
        return [i for i in soap_descriptors]
    
    # 原子数不相同时直接返回 list 即可
    return soap_descriptors

def compute_similarity(cand_soap, ref_soap, kernel_metric="laplacian"):
    """
    Function: Compute the similarity between candidate and reference SOAP descriptors using the specified kernel metric.
    Input:
        cand_soap: Candidate SOAP descriptor
        ref_soap: Reference SOAP descriptor
        kernel_metric: Kernel metric to use for similarity computation (default: laplacian)
    Output:
        Similarity score between candidate and reference SOAP descriptors
    """
    re = AverageKernel(metric=kernel_metric)
    return re.create(cand_soap, ref_soap)

# %%
def compare_and_update_structures(ref_structures, cand_structures, njobs=8, species=["H", "C", "O", "N"], r_cut=10.0, n_max=3, l_max=3, threshold=0.99):
    """
    Function:
    Compare candidate structures with reference structures.
    Update the reference database one molecule by one molecule.

    Input:
        ref_structures: list of ase.Atoms objects, reference structures
        cand_structures: list of ase.Atoms objects, candidate structures
        njobs: int, number of jobs to run in parallel
        species: list of str, species to consider  
        r_cut: float, cutoff radius for SOAP calculation
        n_max: int, number of radial basis functions
        l_max: int, maximum degree of spherical harmonics
        average: str, type of averaging for SOAP calculation
        sparse: bool, whether to use sparse representation for SOAP calculation
        threshold: float, similarity threshold for reducing candidate structures
        log_file: str, path to log file

    Output:
        ref_structures: list of ase.Atoms objects, updated reference structures
        soap_ref: list of soap_descriptors, SOAP descriptors for updated reference structures
    """
    round_num = 0

    while True:
        round_num += 1

        if round_num == 1:
            # 初次计算全部的 SOAP 描述符
            # 这里还可以改进，先计算描述符或直接读入描述符
            soap_ref = compute_soap_descriptors(ref_structures, njobs, species, r_cut, n_max, l_max)
            soap_cand = compute_soap_descriptors(cand_structures, njobs, species, r_cut, n_max, l_max)

            # 并行计算 cand_structures 中每个结构与 ref_structures 中所有结构的相似度
            start_time = time.time()
            re_kernel_results = Parallel(n_jobs=njobs)(delayed(compute_similarity)(soap_cand[i:i+1], soap_ref) for i in range(len(soap_cand)))
            re_kernel = np.vstack(re_kernel_results)
            end_time = time.time()
            logging.info(f"Round {round_num}: Similarity computation completed in {end_time - start_time:.2f} seconds")

            # 选取 cand_structures 中每个结构与 ref_structures 中所有结构的最大相似度
            max_similarity_values = np.max(re_kernel, axis=1)
        
        else:
            # 并行计算 cand_structures 中每个结构与 ref_structures 新加入的结构的相似度
            # 变量覆盖释放内存空间
            ### 这里可以写成一个函数，便于复用
            start_time = time.time()
            re_kernel_results = Parallel(n_jobs=njobs)(delayed(compute_similarity)(soap_cand[i:i+1], [soap_ref[-1]]) for i in range(len(soap_cand)))
            re_kernel = np.vstack(re_kernel_results)
            end_time = time.time()
            logging.info(f"Round {round_num}: Similarity computation completed in {end_time - start_time:.2f} seconds")
            ### 这里可以写成一个函数，便于复用

            # 将原先 max_similarity_values 与新加入的点的堆叠
            max_similarity_values = np.max(np.column_stack((max_similarity_values, np.max(re_kernel, axis=1))), axis=1)


        # 删除 cand_structures 中与 ref_structures 中相似度高于 threshold 的所有结构
        # 更新 soap_cand, cand_structures, max_similarity_values
        old_cand_num = len(cand_structures)
        soap_cand = [soap_cand[i] for i in range(len(soap_cand)) if round(max_similarity_values[i],5) < threshold]
        cand_structures = [cand_structures[i] for i in range(len(cand_structures)) if round(max_similarity_values[i],5) < threshold]
        max_similarity_values = np.array([max_similarity_values[i] 
                                            for i in range(len(max_similarity_values)) if round(max_similarity_values[i],5) < threshold])
        new_cand_num = len(cand_structures)
        logging.info(f"Round {round_num}: Cand structures reduced from {old_cand_num} to {new_cand_num}")

        # 如果 cand_structures 中没有元素，则退出循环
        if new_cand_num == 0:
            break

        # 将 cand_structures 与 ref_structures 中最不相似的结构添加到 ref_structures 中
        min_max_similarity = np.min([round(i,5) for i in max_similarity_values])
        min_max_similarity_index = np.argmin(max_similarity_values)
        ref_structures.append(cand_structures[min_max_similarity_index])
        soap_ref.append(soap_cand[min_max_similarity_index])
        logging.info(f"Round {round_num}: Added structure with min max similarity {min_max_similarity}.")
        logging.info(f"Ref structures: {len(ref_structures)}, Cand structures: {len(cand_structures)}")
        logging.info("---------")


    logging.info(f"No structures remaining in candidate list.")
    logging.info(f"Ref structures: {len(ref_structures)}, Cand structures: {len(cand_structures)}")
    logging.info("---------")
        
    return ref_structures, soap_ref

# %%
def save_soap_to_hdf5(soap_dict, hdf5_name):
    """
    Save SOAP descriptors to an HDF5 file.

    Example input structure:
    defaultdict(list, {
        'C2H3N3O': [
            array([[...], [...], ...]),  # SOAP descriptors for the first molecule
            array([[...], [...], ...])   # SOAP descriptors for the second molecule
        ],
        'C2H6': [
            array([[...], [...], ...])   # SOAP descriptors for another molecule
        ]
    })

    - Each value is an array representing the SOAP descriptors for a molecule, with shape (N, M),
    where N is the number of descriptors and M is the dimension of each descriptor.
    """
    with h5py.File(hdf5_name, "w") as hdf:
        for formula, soap_list in soap_dict.items():
            stacked_soap = np.array(soap_list)
            hdf.create_dataset(formula, data=stacked_soap)
    logging.info(f"SOAP descriptors saved to '{hdf5_name}'")

def read_soap_from_hdf5(hdf5_name):
    """
    Read SOAP descriptors from an HDF5 file.

    Returns:
        defaultdict(list): A dictionary with molecule formulas as keys
        and lists of corresponding SOAP descriptors as values.
    """
    soap_dict = defaultdict(list)

    with h5py.File(hdf5_name, "r") as hdf:
        for formula in hdf.keys():
            soap_descriptors = hdf[formula][:]
            soap_dict[formula].append(soap_descriptors)

    return soap_dict

def defaultdict_profiler(soap_data):
    """
    Print the available formulas and the shape of their corresponding SOAP descriptors.
    """
    formulas = list(soap_data.keys())
    print("Available formulas:", formulas)

    # 遍历每个分子式并读取 SOAP 描述符
    for formula in formulas:
        soap_descriptors = soap_data[formula][:][0]
        print(f"Formula: {formula}, Shape of SOAP descriptors: {soap_descriptors.shape}")
    print("---------")

# %%
# 设置日志记录
logging.basicConfig(level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler("output.log", mode='w'), # 输出到日志文件
                        logging.StreamHandler() # 同时输出到终端
                    ])
logging.info('Log begin')

start_time = time.time()

# 读取数据
ref_structures = read('./t1x/rxn000x.xyz', index=':')
cand_structures = read('./t1x/rxn000x_all.xyz', index=':')

# 比较并更新结构
updated_ref_structures, updated_soap_list = compare_and_update_structures(ref_structures, cand_structures, njobs=24)

# 保存更新后的结构和 SOAP 到 HDF5
soap_dict = defaultdict(list)
for i in range(len(updated_soap_list)):
    soap_result = updated_soap_list[i]
    formula = updated_ref_structures[i].get_chemical_formula()
    soap_dict[formula].append(soap_result)
save_soap_to_hdf5(soap_dict, "updated_ref_soap_descriptors.h5")

# 保存更新后的参考结构
write("updated_ref_structures.xyz", updated_ref_structures)
logging.info("Updated reference structures saved to 'updated_ref_structures.xyz'")

end_time = time.time()
logging.info(f"Done! Total time elapsed: {end_time - start_time:.2f} seconds")
logging.info('Log end')
# Out:
# 2024-10-29 18:46:16,652 - INFO - Log begin
# 2024-10-29 18:46:19,962 - INFO - SOAP descriptors computed in 2.31 seconds
# 2024-10-29 18:46:20,791 - INFO - SOAP descriptors computed in 0.83 seconds
# 2024-10-29 18:52:55,091 - INFO - Round 1: Similarity computation completed in 394.30 seconds
# 2024-10-29 18:52:55,180 - INFO - Round 1: Cand structures reduced from 8068 to 4327
# 2024-10-29 18:52:55,193 - INFO - Round 1: Added structure with min max similarity 0.95547.
# 2024-10-29 18:52:55,193 - INFO - Ref structures: 982, Cand structures: 4327
# 2024-10-29 18:52:55,194 - INFO - ---------
# 2024-10-29 18:52:55,796 - INFO - Round 2: Similarity computation completed in 0.60 seconds
# 2024-10-29 18:52:55,837 - INFO - Round 2: Cand structures reduced from 4327 to 4326
# 2024-10-29 18:52:55,851 - INFO - Round 2: Added structure with min max similarity 0.95671.
# 2024-10-29 18:52:55,851 - INFO - Ref structures: 983, Cand structures: 4326
# 2024-10-29 18:52:55,851 - INFO - ---------
# 2024-10-29 18:52:56,253 - INFO - Round 3: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:52:56,296 - INFO - Round 3: Cand structures reduced from 4326 to 4325
# 2024-10-29 18:52:56,309 - INFO - Round 3: Added structure with min max similarity 0.95703.
# 2024-10-29 18:52:56,309 - INFO - Ref structures: 984, Cand structures: 4325
# 2024-10-29 18:52:56,310 - INFO - ---------
# 2024-10-29 18:52:56,708 - INFO - Round 4: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:52:56,750 - INFO - Round 4: Cand structures reduced from 4325 to 4322
# 2024-10-29 18:52:56,763 - INFO - Round 4: Added structure with min max similarity 0.95743.
# 2024-10-29 18:52:56,764 - INFO - Ref structures: 985, Cand structures: 4322
# 2024-10-29 18:52:56,764 - INFO - ---------
# 2024-10-29 18:52:57,170 - INFO - Round 5: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:52:57,211 - INFO - Round 5: Cand structures reduced from 4322 to 4320
# 2024-10-29 18:52:57,224 - INFO - Round 5: Added structure with min max similarity 0.95862.
# 2024-10-29 18:52:57,224 - INFO - Ref structures: 986, Cand structures: 4320
# 2024-10-29 18:52:57,225 - INFO - ---------
# 2024-10-29 18:52:57,641 - INFO - Round 6: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:52:57,683 - INFO - Round 6: Cand structures reduced from 4320 to 4316
# 2024-10-29 18:52:57,696 - INFO - Round 6: Added structure with min max similarity 0.95872.
# 2024-10-29 18:52:57,696 - INFO - Ref structures: 987, Cand structures: 4316
# 2024-10-29 18:52:57,697 - INFO - ---------
# 2024-10-29 18:52:58,115 - INFO - Round 7: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:52:58,157 - INFO - Round 7: Cand structures reduced from 4316 to 4313
# 2024-10-29 18:52:58,170 - INFO - Round 7: Added structure with min max similarity 0.95877.
# 2024-10-29 18:52:58,170 - INFO - Ref structures: 988, Cand structures: 4313
# 2024-10-29 18:52:58,171 - INFO - ---------
# 2024-10-29 18:52:58,720 - INFO - Round 8: Similarity computation completed in 0.55 seconds
# 2024-10-29 18:52:58,761 - INFO - Round 8: Cand structures reduced from 4313 to 4308
# 2024-10-29 18:52:58,774 - INFO - Round 8: Added structure with min max similarity 0.95886.
# 2024-10-29 18:52:58,775 - INFO - Ref structures: 989, Cand structures: 4308
# 2024-10-29 18:52:58,775 - INFO - ---------
# 2024-10-29 18:52:59,182 - INFO - Round 9: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:52:59,222 - INFO - Round 9: Cand structures reduced from 4308 to 4307
# 2024-10-29 18:52:59,236 - INFO - Round 9: Added structure with min max similarity 0.9598.
# 2024-10-29 18:52:59,236 - INFO - Ref structures: 990, Cand structures: 4307
# 2024-10-29 18:52:59,236 - INFO - ---------
# 2024-10-29 18:52:59,622 - INFO - Round 10: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:52:59,663 - INFO - Round 10: Cand structures reduced from 4307 to 4306
# 2024-10-29 18:52:59,676 - INFO - Round 10: Added structure with min max similarity 0.95984.
# 2024-10-29 18:52:59,676 - INFO - Ref structures: 991, Cand structures: 4306
# 2024-10-29 18:52:59,677 - INFO - ---------
# 2024-10-29 18:53:00,050 - INFO - Round 11: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:00,091 - INFO - Round 11: Cand structures reduced from 4306 to 4304
# 2024-10-29 18:53:00,104 - INFO - Round 11: Added structure with min max similarity 0.96025.
# 2024-10-29 18:53:00,104 - INFO - Ref structures: 992, Cand structures: 4304
# 2024-10-29 18:53:00,105 - INFO - ---------
# 2024-10-29 18:53:00,494 - INFO - Round 12: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:00,535 - INFO - Round 12: Cand structures reduced from 4304 to 4297
# 2024-10-29 18:53:00,548 - INFO - Round 12: Added structure with min max similarity 0.96026.
# 2024-10-29 18:53:00,549 - INFO - Ref structures: 993, Cand structures: 4297
# 2024-10-29 18:53:00,549 - INFO - ---------
# 2024-10-29 18:53:00,940 - INFO - Round 13: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:00,981 - INFO - Round 13: Cand structures reduced from 4297 to 4296
# 2024-10-29 18:53:00,995 - INFO - Round 13: Added structure with min max similarity 0.96033.
# 2024-10-29 18:53:00,995 - INFO - Ref structures: 994, Cand structures: 4296
# 2024-10-29 18:53:00,995 - INFO - ---------
# 2024-10-29 18:53:01,385 - INFO - Round 14: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:01,426 - INFO - Round 14: Cand structures reduced from 4296 to 4295
# 2024-10-29 18:53:01,439 - INFO - Round 14: Added structure with min max similarity 0.96068.
# 2024-10-29 18:53:01,440 - INFO - Ref structures: 995, Cand structures: 4295
# 2024-10-29 18:53:01,440 - INFO - ---------
# 2024-10-29 18:53:01,956 - INFO - Round 15: Similarity computation completed in 0.52 seconds
# 2024-10-29 18:53:01,997 - INFO - Round 15: Cand structures reduced from 4295 to 4293
# 2024-10-29 18:53:02,010 - INFO - Round 15: Added structure with min max similarity 0.96104.
# 2024-10-29 18:53:02,010 - INFO - Ref structures: 996, Cand structures: 4293
# 2024-10-29 18:53:02,010 - INFO - ---------
# 2024-10-29 18:53:02,401 - INFO - Round 16: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:02,442 - INFO - Round 16: Cand structures reduced from 4293 to 4292
# 2024-10-29 18:53:02,455 - INFO - Round 16: Added structure with min max similarity 0.96122.
# 2024-10-29 18:53:02,455 - INFO - Ref structures: 997, Cand structures: 4292
# 2024-10-29 18:53:02,456 - INFO - ---------
# 2024-10-29 18:53:02,856 - INFO - Round 17: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:02,897 - INFO - Round 17: Cand structures reduced from 4292 to 4287
# 2024-10-29 18:53:02,910 - INFO - Round 17: Added structure with min max similarity 0.96122.
# 2024-10-29 18:53:02,911 - INFO - Ref structures: 998, Cand structures: 4287
# 2024-10-29 18:53:02,911 - INFO - ---------
# 2024-10-29 18:53:03,310 - INFO - Round 18: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:03,351 - INFO - Round 18: Cand structures reduced from 4287 to 4286
# 2024-10-29 18:53:03,364 - INFO - Round 18: Added structure with min max similarity 0.96148.
# 2024-10-29 18:53:03,365 - INFO - Ref structures: 999, Cand structures: 4286
# 2024-10-29 18:53:03,365 - INFO - ---------
# 2024-10-29 18:53:03,767 - INFO - Round 19: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:03,808 - INFO - Round 19: Cand structures reduced from 4286 to 4283
# 2024-10-29 18:53:03,821 - INFO - Round 19: Added structure with min max similarity 0.96162.
# 2024-10-29 18:53:03,821 - INFO - Ref structures: 1000, Cand structures: 4283
# 2024-10-29 18:53:03,821 - INFO - ---------
# 2024-10-29 18:53:04,197 - INFO - Round 20: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:04,237 - INFO - Round 20: Cand structures reduced from 4283 to 4282
# 2024-10-29 18:53:04,250 - INFO - Round 20: Added structure with min max similarity 0.96177.
# 2024-10-29 18:53:04,250 - INFO - Ref structures: 1001, Cand structures: 4282
# 2024-10-29 18:53:04,251 - INFO - ---------
# 2024-10-29 18:53:04,817 - INFO - Round 21: Similarity computation completed in 0.57 seconds
# 2024-10-29 18:53:04,859 - INFO - Round 21: Cand structures reduced from 4282 to 4280
# 2024-10-29 18:53:04,872 - INFO - Round 21: Added structure with min max similarity 0.96191.
# 2024-10-29 18:53:04,872 - INFO - Ref structures: 1002, Cand structures: 4280
# 2024-10-29 18:53:04,873 - INFO - ---------
# 2024-10-29 18:53:05,257 - INFO - Round 22: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:05,298 - INFO - Round 22: Cand structures reduced from 4280 to 4279
# 2024-10-29 18:53:05,311 - INFO - Round 22: Added structure with min max similarity 0.96196.
# 2024-10-29 18:53:05,312 - INFO - Ref structures: 1003, Cand structures: 4279
# 2024-10-29 18:53:05,312 - INFO - ---------
# 2024-10-29 18:53:05,696 - INFO - Round 23: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:05,738 - INFO - Round 23: Cand structures reduced from 4279 to 4278
# 2024-10-29 18:53:05,751 - INFO - Round 23: Added structure with min max similarity 0.96208.
# 2024-10-29 18:53:05,751 - INFO - Ref structures: 1004, Cand structures: 4278
# 2024-10-29 18:53:05,751 - INFO - ---------
# 2024-10-29 18:53:06,145 - INFO - Round 24: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:06,186 - INFO - Round 24: Cand structures reduced from 4278 to 4275
# 2024-10-29 18:53:06,199 - INFO - Round 24: Added structure with min max similarity 0.96219.
# 2024-10-29 18:53:06,200 - INFO - Ref structures: 1005, Cand structures: 4275
# 2024-10-29 18:53:06,200 - INFO - ---------
# 2024-10-29 18:53:06,598 - INFO - Round 25: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:06,639 - INFO - Round 25: Cand structures reduced from 4275 to 4274
# 2024-10-29 18:53:06,652 - INFO - Round 25: Added structure with min max similarity 0.96244.
# 2024-10-29 18:53:06,652 - INFO - Ref structures: 1006, Cand structures: 4274
# 2024-10-29 18:53:06,652 - INFO - ---------
# 2024-10-29 18:53:07,038 - INFO - Round 26: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:07,079 - INFO - Round 26: Cand structures reduced from 4274 to 4273
# 2024-10-29 18:53:07,092 - INFO - Round 26: Added structure with min max similarity 0.96253.
# 2024-10-29 18:53:07,092 - INFO - Ref structures: 1007, Cand structures: 4273
# 2024-10-29 18:53:07,093 - INFO - ---------
# 2024-10-29 18:53:07,659 - INFO - Round 27: Similarity computation completed in 0.57 seconds
# 2024-10-29 18:53:07,700 - INFO - Round 27: Cand structures reduced from 4273 to 4272
# 2024-10-29 18:53:07,712 - INFO - Round 27: Added structure with min max similarity 0.96259.
# 2024-10-29 18:53:07,713 - INFO - Ref structures: 1008, Cand structures: 4272
# 2024-10-29 18:53:07,713 - INFO - ---------
# 2024-10-29 18:53:08,096 - INFO - Round 28: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:08,136 - INFO - Round 28: Cand structures reduced from 4272 to 4269
# 2024-10-29 18:53:08,149 - INFO - Round 28: Added structure with min max similarity 0.96262.
# 2024-10-29 18:53:08,149 - INFO - Ref structures: 1009, Cand structures: 4269
# 2024-10-29 18:53:08,149 - INFO - ---------
# 2024-10-29 18:53:08,540 - INFO - Round 29: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:08,580 - INFO - Round 29: Cand structures reduced from 4269 to 4266
# 2024-10-29 18:53:08,593 - INFO - Round 29: Added structure with min max similarity 0.96271.
# 2024-10-29 18:53:08,594 - INFO - Ref structures: 1010, Cand structures: 4266
# 2024-10-29 18:53:08,594 - INFO - ---------
# 2024-10-29 18:53:08,980 - INFO - Round 30: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:09,021 - INFO - Round 30: Cand structures reduced from 4266 to 4265
# 2024-10-29 18:53:09,034 - INFO - Round 30: Added structure with min max similarity 0.96275.
# 2024-10-29 18:53:09,034 - INFO - Ref structures: 1011, Cand structures: 4265
# 2024-10-29 18:53:09,035 - INFO - ---------
# 2024-10-29 18:53:09,421 - INFO - Round 31: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:09,462 - INFO - Round 31: Cand structures reduced from 4265 to 4261
# 2024-10-29 18:53:09,475 - INFO - Round 31: Added structure with min max similarity 0.96277.
# 2024-10-29 18:53:09,475 - INFO - Ref structures: 1012, Cand structures: 4261
# 2024-10-29 18:53:09,476 - INFO - ---------
# 2024-10-29 18:53:09,852 - INFO - Round 32: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:09,893 - INFO - Round 32: Cand structures reduced from 4261 to 4258
# 2024-10-29 18:53:09,905 - INFO - Round 32: Added structure with min max similarity 0.96278.
# 2024-10-29 18:53:09,906 - INFO - Ref structures: 1013, Cand structures: 4258
# 2024-10-29 18:53:09,906 - INFO - ---------
# 2024-10-29 18:53:10,435 - INFO - Round 33: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:10,476 - INFO - Round 33: Cand structures reduced from 4258 to 4254
# 2024-10-29 18:53:10,489 - INFO - Round 33: Added structure with min max similarity 0.96294.
# 2024-10-29 18:53:10,489 - INFO - Ref structures: 1014, Cand structures: 4254
# 2024-10-29 18:53:10,490 - INFO - ---------
# 2024-10-29 18:53:10,860 - INFO - Round 34: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:10,900 - INFO - Round 34: Cand structures reduced from 4254 to 4253
# 2024-10-29 18:53:10,913 - INFO - Round 34: Added structure with min max similarity 0.96306.
# 2024-10-29 18:53:10,914 - INFO - Ref structures: 1015, Cand structures: 4253
# 2024-10-29 18:53:10,914 - INFO - ---------
# 2024-10-29 18:53:11,330 - INFO - Round 35: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:53:11,371 - INFO - Round 35: Cand structures reduced from 4253 to 4250
# 2024-10-29 18:53:11,385 - INFO - Round 35: Added structure with min max similarity 0.96311.
# 2024-10-29 18:53:11,385 - INFO - Ref structures: 1016, Cand structures: 4250
# 2024-10-29 18:53:11,386 - INFO - ---------
# 2024-10-29 18:53:11,779 - INFO - Round 36: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:11,820 - INFO - Round 36: Cand structures reduced from 4250 to 4249
# 2024-10-29 18:53:11,833 - INFO - Round 36: Added structure with min max similarity 0.96319.
# 2024-10-29 18:53:11,833 - INFO - Ref structures: 1017, Cand structures: 4249
# 2024-10-29 18:53:11,834 - INFO - ---------
# 2024-10-29 18:53:12,217 - INFO - Round 37: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:12,258 - INFO - Round 37: Cand structures reduced from 4249 to 4248
# 2024-10-29 18:53:12,271 - INFO - Round 37: Added structure with min max similarity 0.96331.
# 2024-10-29 18:53:12,271 - INFO - Ref structures: 1018, Cand structures: 4248
# 2024-10-29 18:53:12,272 - INFO - ---------
# 2024-10-29 18:53:12,688 - INFO - Round 38: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:53:12,729 - INFO - Round 38: Cand structures reduced from 4248 to 4246
# 2024-10-29 18:53:12,743 - INFO - Round 38: Added structure with min max similarity 0.96333.
# 2024-10-29 18:53:12,743 - INFO - Ref structures: 1019, Cand structures: 4246
# 2024-10-29 18:53:12,743 - INFO - ---------
# 2024-10-29 18:53:13,261 - INFO - Round 39: Similarity computation completed in 0.52 seconds
# 2024-10-29 18:53:13,301 - INFO - Round 39: Cand structures reduced from 4246 to 4245
# 2024-10-29 18:53:13,314 - INFO - Round 39: Added structure with min max similarity 0.96382.
# 2024-10-29 18:53:13,314 - INFO - Ref structures: 1020, Cand structures: 4245
# 2024-10-29 18:53:13,315 - INFO - ---------
# 2024-10-29 18:53:13,731 - INFO - Round 40: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:53:13,773 - INFO - Round 40: Cand structures reduced from 4245 to 4244
# 2024-10-29 18:53:13,786 - INFO - Round 40: Added structure with min max similarity 0.96409.
# 2024-10-29 18:53:13,786 - INFO - Ref structures: 1021, Cand structures: 4244
# 2024-10-29 18:53:13,787 - INFO - ---------
# 2024-10-29 18:53:14,170 - INFO - Round 41: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:14,211 - INFO - Round 41: Cand structures reduced from 4244 to 4240
# 2024-10-29 18:53:14,224 - INFO - Round 41: Added structure with min max similarity 0.96414.
# 2024-10-29 18:53:14,224 - INFO - Ref structures: 1022, Cand structures: 4240
# 2024-10-29 18:53:14,224 - INFO - ---------
# 2024-10-29 18:53:14,605 - INFO - Round 42: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:14,646 - INFO - Round 42: Cand structures reduced from 4240 to 4239
# 2024-10-29 18:53:14,659 - INFO - Round 42: Added structure with min max similarity 0.96418.
# 2024-10-29 18:53:14,659 - INFO - Ref structures: 1023, Cand structures: 4239
# 2024-10-29 18:53:14,660 - INFO - ---------
# 2024-10-29 18:53:15,046 - INFO - Round 43: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:15,087 - INFO - Round 43: Cand structures reduced from 4239 to 4236
# 2024-10-29 18:53:15,099 - INFO - Round 43: Added structure with min max similarity 0.96451.
# 2024-10-29 18:53:15,100 - INFO - Ref structures: 1024, Cand structures: 4236
# 2024-10-29 18:53:15,100 - INFO - ---------
# 2024-10-29 18:53:15,482 - INFO - Round 44: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:15,524 - INFO - Round 44: Cand structures reduced from 4236 to 4231
# 2024-10-29 18:53:15,537 - INFO - Round 44: Added structure with min max similarity 0.96453.
# 2024-10-29 18:53:15,537 - INFO - Ref structures: 1025, Cand structures: 4231
# 2024-10-29 18:53:15,538 - INFO - ---------
# 2024-10-29 18:53:16,067 - INFO - Round 45: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:16,107 - INFO - Round 45: Cand structures reduced from 4231 to 4230
# 2024-10-29 18:53:16,120 - INFO - Round 45: Added structure with min max similarity 0.96508.
# 2024-10-29 18:53:16,121 - INFO - Ref structures: 1026, Cand structures: 4230
# 2024-10-29 18:53:16,121 - INFO - ---------
# 2024-10-29 18:53:16,501 - INFO - Round 46: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:16,541 - INFO - Round 46: Cand structures reduced from 4230 to 4229
# 2024-10-29 18:53:16,554 - INFO - Round 46: Added structure with min max similarity 0.96509.
# 2024-10-29 18:53:16,554 - INFO - Ref structures: 1027, Cand structures: 4229
# 2024-10-29 18:53:16,555 - INFO - ---------
# 2024-10-29 18:53:16,955 - INFO - Round 47: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:16,997 - INFO - Round 47: Cand structures reduced from 4229 to 4228
# 2024-10-29 18:53:17,010 - INFO - Round 47: Added structure with min max similarity 0.96516.
# 2024-10-29 18:53:17,010 - INFO - Ref structures: 1028, Cand structures: 4228
# 2024-10-29 18:53:17,010 - INFO - ---------
# 2024-10-29 18:53:17,404 - INFO - Round 48: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:17,444 - INFO - Round 48: Cand structures reduced from 4228 to 4227
# 2024-10-29 18:53:17,457 - INFO - Round 48: Added structure with min max similarity 0.96516.
# 2024-10-29 18:53:17,458 - INFO - Ref structures: 1029, Cand structures: 4227
# 2024-10-29 18:53:17,458 - INFO - ---------
# 2024-10-29 18:53:17,846 - INFO - Round 49: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:17,887 - INFO - Round 49: Cand structures reduced from 4227 to 4220
# 2024-10-29 18:53:17,899 - INFO - Round 49: Added structure with min max similarity 0.9652.
# 2024-10-29 18:53:17,900 - INFO - Ref structures: 1030, Cand structures: 4220
# 2024-10-29 18:53:17,900 - INFO - ---------
# 2024-10-29 18:53:18,303 - INFO - Round 50: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:18,343 - INFO - Round 50: Cand structures reduced from 4220 to 4219
# 2024-10-29 18:53:18,356 - INFO - Round 50: Added structure with min max similarity 0.9652.
# 2024-10-29 18:53:18,357 - INFO - Ref structures: 1031, Cand structures: 4219
# 2024-10-29 18:53:18,357 - INFO - ---------
# 2024-10-29 18:53:18,747 - INFO - Round 51: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:18,787 - INFO - Round 51: Cand structures reduced from 4219 to 4218
# 2024-10-29 18:53:18,800 - INFO - Round 51: Added structure with min max similarity 0.96523.
# 2024-10-29 18:53:18,800 - INFO - Ref structures: 1032, Cand structures: 4218
# 2024-10-29 18:53:18,800 - INFO - ---------
# 2024-10-29 18:53:19,318 - INFO - Round 52: Similarity computation completed in 0.52 seconds
# 2024-10-29 18:53:19,358 - INFO - Round 52: Cand structures reduced from 4218 to 4217
# 2024-10-29 18:53:19,371 - INFO - Round 52: Added structure with min max similarity 0.96537.
# 2024-10-29 18:53:19,371 - INFO - Ref structures: 1033, Cand structures: 4217
# 2024-10-29 18:53:19,372 - INFO - ---------
# 2024-10-29 18:53:19,772 - INFO - Round 53: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:19,813 - INFO - Round 53: Cand structures reduced from 4217 to 4211
# 2024-10-29 18:53:19,826 - INFO - Round 53: Added structure with min max similarity 0.96537.
# 2024-10-29 18:53:19,826 - INFO - Ref structures: 1034, Cand structures: 4211
# 2024-10-29 18:53:19,826 - INFO - ---------
# 2024-10-29 18:53:20,236 - INFO - Round 54: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:20,277 - INFO - Round 54: Cand structures reduced from 4211 to 4197
# 2024-10-29 18:53:20,289 - INFO - Round 54: Added structure with min max similarity 0.9654.
# 2024-10-29 18:53:20,290 - INFO - Ref structures: 1035, Cand structures: 4197
# 2024-10-29 18:53:20,290 - INFO - ---------
# 2024-10-29 18:53:20,684 - INFO - Round 55: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:20,724 - INFO - Round 55: Cand structures reduced from 4197 to 4194
# 2024-10-29 18:53:20,738 - INFO - Round 55: Added structure with min max similarity 0.96561.
# 2024-10-29 18:53:20,738 - INFO - Ref structures: 1036, Cand structures: 4194
# 2024-10-29 18:53:20,738 - INFO - ---------
# 2024-10-29 18:53:21,143 - INFO - Round 56: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:21,182 - INFO - Round 56: Cand structures reduced from 4194 to 4190
# 2024-10-29 18:53:21,196 - INFO - Round 56: Added structure with min max similarity 0.96561.
# 2024-10-29 18:53:21,196 - INFO - Ref structures: 1037, Cand structures: 4190
# 2024-10-29 18:53:21,196 - INFO - ---------
# 2024-10-29 18:53:21,588 - INFO - Round 57: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:21,628 - INFO - Round 57: Cand structures reduced from 4190 to 4188
# 2024-10-29 18:53:21,641 - INFO - Round 57: Added structure with min max similarity 0.9657.
# 2024-10-29 18:53:21,641 - INFO - Ref structures: 1038, Cand structures: 4188
# 2024-10-29 18:53:21,642 - INFO - ---------
# 2024-10-29 18:53:22,223 - INFO - Round 58: Similarity computation completed in 0.58 seconds
# 2024-10-29 18:53:22,263 - INFO - Round 58: Cand structures reduced from 4188 to 4187
# 2024-10-29 18:53:22,276 - INFO - Round 58: Added structure with min max similarity 0.96582.
# 2024-10-29 18:53:22,276 - INFO - Ref structures: 1039, Cand structures: 4187
# 2024-10-29 18:53:22,277 - INFO - ---------
# 2024-10-29 18:53:22,685 - INFO - Round 59: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:22,725 - INFO - Round 59: Cand structures reduced from 4187 to 4186
# 2024-10-29 18:53:22,738 - INFO - Round 59: Added structure with min max similarity 0.96585.
# 2024-10-29 18:53:22,738 - INFO - Ref structures: 1040, Cand structures: 4186
# 2024-10-29 18:53:22,738 - INFO - ---------
# 2024-10-29 18:53:23,136 - INFO - Round 60: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:23,176 - INFO - Round 60: Cand structures reduced from 4186 to 4184
# 2024-10-29 18:53:23,189 - INFO - Round 60: Added structure with min max similarity 0.96586.
# 2024-10-29 18:53:23,189 - INFO - Ref structures: 1041, Cand structures: 4184
# 2024-10-29 18:53:23,190 - INFO - ---------
# 2024-10-29 18:53:23,578 - INFO - Round 61: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:23,618 - INFO - Round 61: Cand structures reduced from 4184 to 4183
# 2024-10-29 18:53:23,631 - INFO - Round 61: Added structure with min max similarity 0.96586.
# 2024-10-29 18:53:23,631 - INFO - Ref structures: 1042, Cand structures: 4183
# 2024-10-29 18:53:23,632 - INFO - ---------
# 2024-10-29 18:53:24,045 - INFO - Round 62: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:24,085 - INFO - Round 62: Cand structures reduced from 4183 to 4182
# 2024-10-29 18:53:24,098 - INFO - Round 62: Added structure with min max similarity 0.96613.
# 2024-10-29 18:53:24,098 - INFO - Ref structures: 1043, Cand structures: 4182
# 2024-10-29 18:53:24,098 - INFO - ---------
# 2024-10-29 18:53:24,509 - INFO - Round 63: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:24,550 - INFO - Round 63: Cand structures reduced from 4182 to 4181
# 2024-10-29 18:53:24,563 - INFO - Round 63: Added structure with min max similarity 0.96641.
# 2024-10-29 18:53:24,563 - INFO - Ref structures: 1044, Cand structures: 4181
# 2024-10-29 18:53:24,564 - INFO - ---------
# 2024-10-29 18:53:25,115 - INFO - Round 64: Similarity computation completed in 0.55 seconds
# 2024-10-29 18:53:25,154 - INFO - Round 64: Cand structures reduced from 4181 to 4180
# 2024-10-29 18:53:25,167 - INFO - Round 64: Added structure with min max similarity 0.96645.
# 2024-10-29 18:53:25,168 - INFO - Ref structures: 1045, Cand structures: 4180
# 2024-10-29 18:53:25,168 - INFO - ---------
# 2024-10-29 18:53:25,576 - INFO - Round 65: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:25,617 - INFO - Round 65: Cand structures reduced from 4180 to 4157
# 2024-10-29 18:53:25,629 - INFO - Round 65: Added structure with min max similarity 0.96657.
# 2024-10-29 18:53:25,629 - INFO - Ref structures: 1046, Cand structures: 4157
# 2024-10-29 18:53:25,630 - INFO - ---------
# 2024-10-29 18:53:26,019 - INFO - Round 66: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:26,059 - INFO - Round 66: Cand structures reduced from 4157 to 4154
# 2024-10-29 18:53:26,072 - INFO - Round 66: Added structure with min max similarity 0.96661.
# 2024-10-29 18:53:26,073 - INFO - Ref structures: 1047, Cand structures: 4154
# 2024-10-29 18:53:26,073 - INFO - ---------
# 2024-10-29 18:53:26,461 - INFO - Round 67: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:26,502 - INFO - Round 67: Cand structures reduced from 4154 to 4153
# 2024-10-29 18:53:26,515 - INFO - Round 67: Added structure with min max similarity 0.96667.
# 2024-10-29 18:53:26,516 - INFO - Ref structures: 1048, Cand structures: 4153
# 2024-10-29 18:53:26,516 - INFO - ---------
# 2024-10-29 18:53:26,903 - INFO - Round 68: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:26,943 - INFO - Round 68: Cand structures reduced from 4153 to 4152
# 2024-10-29 18:53:26,956 - INFO - Round 68: Added structure with min max similarity 0.9667.
# 2024-10-29 18:53:26,956 - INFO - Ref structures: 1049, Cand structures: 4152
# 2024-10-29 18:53:26,957 - INFO - ---------
# 2024-10-29 18:53:27,348 - INFO - Round 69: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:27,388 - INFO - Round 69: Cand structures reduced from 4152 to 4149
# 2024-10-29 18:53:27,401 - INFO - Round 69: Added structure with min max similarity 0.9668.
# 2024-10-29 18:53:27,401 - INFO - Ref structures: 1050, Cand structures: 4149
# 2024-10-29 18:53:27,401 - INFO - ---------
# 2024-10-29 18:53:27,792 - INFO - Round 70: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:27,831 - INFO - Round 70: Cand structures reduced from 4149 to 4148
# 2024-10-29 18:53:27,844 - INFO - Round 70: Added structure with min max similarity 0.9669.
# 2024-10-29 18:53:27,844 - INFO - Ref structures: 1051, Cand structures: 4148
# 2024-10-29 18:53:27,844 - INFO - ---------
# 2024-10-29 18:53:28,352 - INFO - Round 71: Similarity computation completed in 0.51 seconds
# 2024-10-29 18:53:28,391 - INFO - Round 71: Cand structures reduced from 4148 to 4145
# 2024-10-29 18:53:28,404 - INFO - Round 71: Added structure with min max similarity 0.96691.
# 2024-10-29 18:53:28,404 - INFO - Ref structures: 1052, Cand structures: 4145
# 2024-10-29 18:53:28,404 - INFO - ---------
# 2024-10-29 18:53:28,799 - INFO - Round 72: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:28,839 - INFO - Round 72: Cand structures reduced from 4145 to 4142
# 2024-10-29 18:53:28,851 - INFO - Round 72: Added structure with min max similarity 0.96741.
# 2024-10-29 18:53:28,852 - INFO - Ref structures: 1053, Cand structures: 4142
# 2024-10-29 18:53:28,852 - INFO - ---------
# 2024-10-29 18:53:29,253 - INFO - Round 73: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:29,292 - INFO - Round 73: Cand structures reduced from 4142 to 4140
# 2024-10-29 18:53:29,305 - INFO - Round 73: Added structure with min max similarity 0.96755.
# 2024-10-29 18:53:29,305 - INFO - Ref structures: 1054, Cand structures: 4140
# 2024-10-29 18:53:29,305 - INFO - ---------
# 2024-10-29 18:53:29,686 - INFO - Round 74: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:29,725 - INFO - Round 74: Cand structures reduced from 4140 to 4139
# 2024-10-29 18:53:29,738 - INFO - Round 74: Added structure with min max similarity 0.96757.
# 2024-10-29 18:53:29,738 - INFO - Ref structures: 1055, Cand structures: 4139
# 2024-10-29 18:53:29,738 - INFO - ---------
# 2024-10-29 18:53:30,132 - INFO - Round 75: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:30,172 - INFO - Round 75: Cand structures reduced from 4139 to 4136
# 2024-10-29 18:53:30,185 - INFO - Round 75: Added structure with min max similarity 0.96758.
# 2024-10-29 18:53:30,185 - INFO - Ref structures: 1056, Cand structures: 4136
# 2024-10-29 18:53:30,186 - INFO - ---------
# 2024-10-29 18:53:30,575 - INFO - Round 76: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:30,615 - INFO - Round 76: Cand structures reduced from 4136 to 4135
# 2024-10-29 18:53:30,627 - INFO - Round 76: Added structure with min max similarity 0.96772.
# 2024-10-29 18:53:30,628 - INFO - Ref structures: 1057, Cand structures: 4135
# 2024-10-29 18:53:30,628 - INFO - ---------
# 2024-10-29 18:53:31,159 - INFO - Round 77: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:31,199 - INFO - Round 77: Cand structures reduced from 4135 to 4133
# 2024-10-29 18:53:31,212 - INFO - Round 77: Added structure with min max similarity 0.96773.
# 2024-10-29 18:53:31,213 - INFO - Ref structures: 1058, Cand structures: 4133
# 2024-10-29 18:53:31,213 - INFO - ---------
# 2024-10-29 18:53:31,612 - INFO - Round 78: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:31,652 - INFO - Round 78: Cand structures reduced from 4133 to 4132
# 2024-10-29 18:53:31,664 - INFO - Round 78: Added structure with min max similarity 0.96775.
# 2024-10-29 18:53:31,665 - INFO - Ref structures: 1059, Cand structures: 4132
# 2024-10-29 18:53:31,665 - INFO - ---------
# 2024-10-29 18:53:32,086 - INFO - Round 79: Similarity computation completed in 0.42 seconds
# 2024-10-29 18:53:32,126 - INFO - Round 79: Cand structures reduced from 4132 to 4125
# 2024-10-29 18:53:32,139 - INFO - Round 79: Added structure with min max similarity 0.96776.
# 2024-10-29 18:53:32,139 - INFO - Ref structures: 1060, Cand structures: 4125
# 2024-10-29 18:53:32,140 - INFO - ---------
# 2024-10-29 18:53:32,545 - INFO - Round 80: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:32,586 - INFO - Round 80: Cand structures reduced from 4125 to 4124
# 2024-10-29 18:53:32,598 - INFO - Round 80: Added structure with min max similarity 0.96785.
# 2024-10-29 18:53:32,599 - INFO - Ref structures: 1061, Cand structures: 4124
# 2024-10-29 18:53:32,599 - INFO - ---------
# 2024-10-29 18:53:33,001 - INFO - Round 81: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:33,040 - INFO - Round 81: Cand structures reduced from 4124 to 4123
# 2024-10-29 18:53:33,053 - INFO - Round 81: Added structure with min max similarity 0.9679.
# 2024-10-29 18:53:33,053 - INFO - Ref structures: 1062, Cand structures: 4123
# 2024-10-29 18:53:33,053 - INFO - ---------
# 2024-10-29 18:53:33,465 - INFO - Round 82: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:33,505 - INFO - Round 82: Cand structures reduced from 4123 to 4122
# 2024-10-29 18:53:33,518 - INFO - Round 82: Added structure with min max similarity 0.96797.
# 2024-10-29 18:53:33,518 - INFO - Ref structures: 1063, Cand structures: 4122
# 2024-10-29 18:53:33,519 - INFO - ---------
# 2024-10-29 18:53:33,918 - INFO - Round 83: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:33,957 - INFO - Round 83: Cand structures reduced from 4122 to 4121
# 2024-10-29 18:53:33,969 - INFO - Round 83: Added structure with min max similarity 0.96807.
# 2024-10-29 18:53:33,970 - INFO - Ref structures: 1064, Cand structures: 4121
# 2024-10-29 18:53:33,970 - INFO - ---------
# 2024-10-29 18:53:34,501 - INFO - Round 84: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:34,540 - INFO - Round 84: Cand structures reduced from 4121 to 4120
# 2024-10-29 18:53:34,552 - INFO - Round 84: Added structure with min max similarity 0.96817.
# 2024-10-29 18:53:34,553 - INFO - Ref structures: 1065, Cand structures: 4120
# 2024-10-29 18:53:34,553 - INFO - ---------
# 2024-10-29 18:53:34,944 - INFO - Round 85: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:34,984 - INFO - Round 85: Cand structures reduced from 4120 to 4118
# 2024-10-29 18:53:34,996 - INFO - Round 85: Added structure with min max similarity 0.96856.
# 2024-10-29 18:53:34,997 - INFO - Ref structures: 1066, Cand structures: 4118
# 2024-10-29 18:53:34,997 - INFO - ---------
# 2024-10-29 18:53:35,399 - INFO - Round 86: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:35,440 - INFO - Round 86: Cand structures reduced from 4118 to 4111
# 2024-10-29 18:53:35,453 - INFO - Round 86: Added structure with min max similarity 0.96861.
# 2024-10-29 18:53:35,453 - INFO - Ref structures: 1067, Cand structures: 4111
# 2024-10-29 18:53:35,453 - INFO - ---------
# 2024-10-29 18:53:35,843 - INFO - Round 87: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:35,882 - INFO - Round 87: Cand structures reduced from 4111 to 4110
# 2024-10-29 18:53:35,895 - INFO - Round 87: Added structure with min max similarity 0.96864.
# 2024-10-29 18:53:35,895 - INFO - Ref structures: 1068, Cand structures: 4110
# 2024-10-29 18:53:35,895 - INFO - ---------
# 2024-10-29 18:53:36,308 - INFO - Round 88: Similarity computation completed in 0.41 seconds
# 2024-10-29 18:53:36,347 - INFO - Round 88: Cand structures reduced from 4110 to 4109
# 2024-10-29 18:53:36,359 - INFO - Round 88: Added structure with min max similarity 0.96869.
# 2024-10-29 18:53:36,360 - INFO - Ref structures: 1069, Cand structures: 4109
# 2024-10-29 18:53:36,360 - INFO - ---------
# 2024-10-29 18:53:36,740 - INFO - Round 89: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:36,778 - INFO - Round 89: Cand structures reduced from 4109 to 4104
# 2024-10-29 18:53:36,791 - INFO - Round 89: Added structure with min max similarity 0.96876.
# 2024-10-29 18:53:36,791 - INFO - Ref structures: 1070, Cand structures: 4104
# 2024-10-29 18:53:36,791 - INFO - ---------
# 2024-10-29 18:53:37,379 - INFO - Round 90: Similarity computation completed in 0.59 seconds
# 2024-10-29 18:53:37,419 - INFO - Round 90: Cand structures reduced from 4104 to 4101
# 2024-10-29 18:53:37,431 - INFO - Round 90: Added structure with min max similarity 0.9689.
# 2024-10-29 18:53:37,432 - INFO - Ref structures: 1071, Cand structures: 4101
# 2024-10-29 18:53:37,432 - INFO - ---------
# 2024-10-29 18:53:37,821 - INFO - Round 91: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:37,862 - INFO - Round 91: Cand structures reduced from 4101 to 4097
# 2024-10-29 18:53:37,874 - INFO - Round 91: Added structure with min max similarity 0.96894.
# 2024-10-29 18:53:37,874 - INFO - Ref structures: 1072, Cand structures: 4097
# 2024-10-29 18:53:37,875 - INFO - ---------
# 2024-10-29 18:53:38,258 - INFO - Round 92: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:38,297 - INFO - Round 92: Cand structures reduced from 4097 to 4094
# 2024-10-29 18:53:38,309 - INFO - Round 92: Added structure with min max similarity 0.96903.
# 2024-10-29 18:53:38,309 - INFO - Ref structures: 1073, Cand structures: 4094
# 2024-10-29 18:53:38,310 - INFO - ---------
# 2024-10-29 18:53:38,702 - INFO - Round 93: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:38,741 - INFO - Round 93: Cand structures reduced from 4094 to 4092
# 2024-10-29 18:53:38,754 - INFO - Round 93: Added structure with min max similarity 0.96908.
# 2024-10-29 18:53:38,754 - INFO - Ref structures: 1074, Cand structures: 4092
# 2024-10-29 18:53:38,754 - INFO - ---------
# 2024-10-29 18:53:39,138 - INFO - Round 94: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:39,177 - INFO - Round 94: Cand structures reduced from 4092 to 4089
# 2024-10-29 18:53:39,189 - INFO - Round 94: Added structure with min max similarity 0.96908.
# 2024-10-29 18:53:39,190 - INFO - Ref structures: 1075, Cand structures: 4089
# 2024-10-29 18:53:39,190 - INFO - ---------
# 2024-10-29 18:53:39,571 - INFO - Round 95: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:39,610 - INFO - Round 95: Cand structures reduced from 4089 to 4088
# 2024-10-29 18:53:39,624 - INFO - Round 95: Added structure with min max similarity 0.96916.
# 2024-10-29 18:53:39,624 - INFO - Ref structures: 1076, Cand structures: 4088
# 2024-10-29 18:53:39,624 - INFO - ---------
# 2024-10-29 18:53:40,021 - INFO - Round 96: Similarity computation completed in 0.40 seconds
# 2024-10-29 18:53:40,060 - INFO - Round 96: Cand structures reduced from 4088 to 4087
# 2024-10-29 18:53:40,073 - INFO - Round 96: Added structure with min max similarity 0.96923.
# 2024-10-29 18:53:40,073 - INFO - Ref structures: 1077, Cand structures: 4087
# 2024-10-29 18:53:40,073 - INFO - ---------
# 2024-10-29 18:53:40,607 - INFO - Round 97: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:40,646 - INFO - Round 97: Cand structures reduced from 4087 to 4086
# 2024-10-29 18:53:40,659 - INFO - Round 97: Added structure with min max similarity 0.96926.
# 2024-10-29 18:53:40,659 - INFO - Ref structures: 1078, Cand structures: 4086
# 2024-10-29 18:53:40,659 - INFO - ---------
# 2024-10-29 18:53:41,051 - INFO - Round 98: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:41,090 - INFO - Round 98: Cand structures reduced from 4086 to 4083
# 2024-10-29 18:53:41,103 - INFO - Round 98: Added structure with min max similarity 0.96927.
# 2024-10-29 18:53:41,103 - INFO - Ref structures: 1079, Cand structures: 4083
# 2024-10-29 18:53:41,104 - INFO - ---------
# 2024-10-29 18:53:41,474 - INFO - Round 99: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:41,514 - INFO - Round 99: Cand structures reduced from 4083 to 4081
# 2024-10-29 18:53:41,527 - INFO - Round 99: Added structure with min max similarity 0.96927.
# 2024-10-29 18:53:41,527 - INFO - Ref structures: 1080, Cand structures: 4081
# 2024-10-29 18:53:41,527 - INFO - ---------
# 2024-10-29 18:53:41,914 - INFO - Round 100: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:41,954 - INFO - Round 100: Cand structures reduced from 4081 to 4079
# 2024-10-29 18:53:41,968 - INFO - Round 100: Added structure with min max similarity 0.96938.
# 2024-10-29 18:53:41,968 - INFO - Ref structures: 1081, Cand structures: 4079
# 2024-10-29 18:53:41,969 - INFO - ---------
# 2024-10-29 18:53:42,348 - INFO - Round 101: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:42,386 - INFO - Round 101: Cand structures reduced from 4079 to 4078
# 2024-10-29 18:53:42,399 - INFO - Round 101: Added structure with min max similarity 0.9694.
# 2024-10-29 18:53:42,399 - INFO - Ref structures: 1082, Cand structures: 4078
# 2024-10-29 18:53:42,400 - INFO - ---------
# 2024-10-29 18:53:42,781 - INFO - Round 102: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:42,819 - INFO - Round 102: Cand structures reduced from 4078 to 4077
# 2024-10-29 18:53:42,832 - INFO - Round 102: Added structure with min max similarity 0.96947.
# 2024-10-29 18:53:42,833 - INFO - Ref structures: 1083, Cand structures: 4077
# 2024-10-29 18:53:42,833 - INFO - ---------
# 2024-10-29 18:53:43,223 - INFO - Round 103: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:43,261 - INFO - Round 103: Cand structures reduced from 4077 to 4076
# 2024-10-29 18:53:43,274 - INFO - Round 103: Added structure with min max similarity 0.96949.
# 2024-10-29 18:53:43,274 - INFO - Ref structures: 1084, Cand structures: 4076
# 2024-10-29 18:53:43,274 - INFO - ---------
# 2024-10-29 18:53:43,837 - INFO - Round 104: Similarity computation completed in 0.56 seconds
# 2024-10-29 18:53:43,875 - INFO - Round 104: Cand structures reduced from 4076 to 4074
# 2024-10-29 18:53:43,888 - INFO - Round 104: Added structure with min max similarity 0.96955.
# 2024-10-29 18:53:43,888 - INFO - Ref structures: 1085, Cand structures: 4074
# 2024-10-29 18:53:43,888 - INFO - ---------
# 2024-10-29 18:53:44,266 - INFO - Round 105: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:44,305 - INFO - Round 105: Cand structures reduced from 4074 to 4073
# 2024-10-29 18:53:44,318 - INFO - Round 105: Added structure with min max similarity 0.9697.
# 2024-10-29 18:53:44,318 - INFO - Ref structures: 1086, Cand structures: 4073
# 2024-10-29 18:53:44,318 - INFO - ---------
# 2024-10-29 18:53:44,703 - INFO - Round 106: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:44,742 - INFO - Round 106: Cand structures reduced from 4073 to 4072
# 2024-10-29 18:53:44,754 - INFO - Round 106: Added structure with min max similarity 0.96971.
# 2024-10-29 18:53:44,755 - INFO - Ref structures: 1087, Cand structures: 4072
# 2024-10-29 18:53:44,755 - INFO - ---------
# 2024-10-29 18:53:45,143 - INFO - Round 107: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:45,181 - INFO - Round 107: Cand structures reduced from 4072 to 4066
# 2024-10-29 18:53:45,194 - INFO - Round 107: Added structure with min max similarity 0.96973.
# 2024-10-29 18:53:45,194 - INFO - Ref structures: 1088, Cand structures: 4066
# 2024-10-29 18:53:45,195 - INFO - ---------
# 2024-10-29 18:53:45,583 - INFO - Round 108: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:45,622 - INFO - Round 108: Cand structures reduced from 4066 to 4064
# 2024-10-29 18:53:45,634 - INFO - Round 108: Added structure with min max similarity 0.96977.
# 2024-10-29 18:53:45,635 - INFO - Ref structures: 1089, Cand structures: 4064
# 2024-10-29 18:53:45,635 - INFO - ---------
# 2024-10-29 18:53:46,013 - INFO - Round 109: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:46,053 - INFO - Round 109: Cand structures reduced from 4064 to 4061
# 2024-10-29 18:53:46,065 - INFO - Round 109: Added structure with min max similarity 0.9698.
# 2024-10-29 18:53:46,065 - INFO - Ref structures: 1090, Cand structures: 4061
# 2024-10-29 18:53:46,066 - INFO - ---------
# 2024-10-29 18:53:46,592 - INFO - Round 110: Similarity computation completed in 0.53 seconds
# 2024-10-29 18:53:46,632 - INFO - Round 110: Cand structures reduced from 4061 to 4059
# 2024-10-29 18:53:46,645 - INFO - Round 110: Added structure with min max similarity 0.96987.
# 2024-10-29 18:53:46,645 - INFO - Ref structures: 1091, Cand structures: 4059
# 2024-10-29 18:53:46,645 - INFO - ---------
# 2024-10-29 18:53:47,022 - INFO - Round 111: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:47,061 - INFO - Round 111: Cand structures reduced from 4059 to 4058
# 2024-10-29 18:53:47,073 - INFO - Round 111: Added structure with min max similarity 0.96987.
# 2024-10-29 18:53:47,074 - INFO - Ref structures: 1092, Cand structures: 4058
# 2024-10-29 18:53:47,074 - INFO - ---------
# 2024-10-29 18:53:47,450 - INFO - Round 112: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:47,489 - INFO - Round 112: Cand structures reduced from 4058 to 4056
# 2024-10-29 18:53:47,502 - INFO - Round 112: Added structure with min max similarity 0.96988.
# 2024-10-29 18:53:47,502 - INFO - Ref structures: 1093, Cand structures: 4056
# 2024-10-29 18:53:47,502 - INFO - ---------
# 2024-10-29 18:53:47,882 - INFO - Round 113: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:47,920 - INFO - Round 113: Cand structures reduced from 4056 to 4055
# 2024-10-29 18:53:47,933 - INFO - Round 113: Added structure with min max similarity 0.96991.
# 2024-10-29 18:53:47,933 - INFO - Ref structures: 1094, Cand structures: 4055
# 2024-10-29 18:53:47,933 - INFO - ---------
# 2024-10-29 18:53:48,301 - INFO - Round 114: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:48,340 - INFO - Round 114: Cand structures reduced from 4055 to 4037
# 2024-10-29 18:53:48,352 - INFO - Round 114: Added structure with min max similarity 0.96999.
# 2024-10-29 18:53:48,353 - INFO - Ref structures: 1095, Cand structures: 4037
# 2024-10-29 18:53:48,353 - INFO - ---------
# 2024-10-29 18:53:48,742 - INFO - Round 115: Similarity computation completed in 0.39 seconds
# 2024-10-29 18:53:48,782 - INFO - Round 115: Cand structures reduced from 4037 to 4032
# 2024-10-29 18:53:48,794 - INFO - Round 115: Added structure with min max similarity 0.97001.
# 2024-10-29 18:53:48,794 - INFO - Ref structures: 1096, Cand structures: 4032
# 2024-10-29 18:53:48,795 - INFO - ---------
# 2024-10-29 18:53:49,159 - INFO - Round 116: Similarity computation completed in 0.36 seconds
# 2024-10-29 18:53:49,198 - INFO - Round 116: Cand structures reduced from 4032 to 4029
# 2024-10-29 18:53:49,210 - INFO - Round 116: Added structure with min max similarity 0.97007.
# 2024-10-29 18:53:49,210 - INFO - Ref structures: 1097, Cand structures: 4029
# 2024-10-29 18:53:49,211 - INFO - ---------
# 2024-10-29 18:53:49,715 - INFO - Round 117: Similarity computation completed in 0.50 seconds
# 2024-10-29 18:53:49,754 - INFO - Round 117: Cand structures reduced from 4029 to 4025
# 2024-10-29 18:53:49,766 - INFO - Round 117: Added structure with min max similarity 0.97007.
# 2024-10-29 18:53:49,766 - INFO - Ref structures: 1098, Cand structures: 4025
# 2024-10-29 18:53:49,767 - INFO - ---------
# 2024-10-29 18:53:50,133 - INFO - Round 118: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:50,172 - INFO - Round 118: Cand structures reduced from 4025 to 4021
# 2024-10-29 18:53:50,184 - INFO - Round 118: Added structure with min max similarity 0.97019.
# 2024-10-29 18:53:50,184 - INFO - Ref structures: 1099, Cand structures: 4021
# 2024-10-29 18:53:50,185 - INFO - ---------
# 2024-10-29 18:53:50,554 - INFO - Round 119: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:50,593 - INFO - Round 119: Cand structures reduced from 4021 to 4016
# 2024-10-29 18:53:50,605 - INFO - Round 119: Added structure with min max similarity 0.97023.
# 2024-10-29 18:53:50,606 - INFO - Ref structures: 1100, Cand structures: 4016
# 2024-10-29 18:53:50,606 - INFO - ---------
# 2024-10-29 18:53:50,986 - INFO - Round 120: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:51,025 - INFO - Round 120: Cand structures reduced from 4016 to 4015
# 2024-10-29 18:53:51,037 - INFO - Round 120: Added structure with min max similarity 0.97029.
# 2024-10-29 18:53:51,038 - INFO - Ref structures: 1101, Cand structures: 4015
# 2024-10-29 18:53:51,038 - INFO - ---------
# 2024-10-29 18:53:51,402 - INFO - Round 121: Similarity computation completed in 0.36 seconds
# 2024-10-29 18:53:51,441 - INFO - Round 121: Cand structures reduced from 4015 to 4012
# 2024-10-29 18:53:51,453 - INFO - Round 121: Added structure with min max similarity 0.97032.
# 2024-10-29 18:53:51,453 - INFO - Ref structures: 1102, Cand structures: 4012
# 2024-10-29 18:53:51,454 - INFO - ---------
# 2024-10-29 18:53:51,820 - INFO - Round 122: Similarity computation completed in 0.37 seconds
# 2024-10-29 18:53:51,858 - INFO - Round 122: Cand structures reduced from 4012 to 4010
# 2024-10-29 18:53:51,870 - INFO - Round 122: Added structure with min max similarity 0.97033.
# 2024-10-29 18:53:51,870 - INFO - Ref structures: 1103, Cand structures: 4010
# 2024-10-29 18:53:51,871 - INFO - ---------
# 2024-10-29 18:53:52,255 - INFO - Round 123: Similarity computation completed in 0.38 seconds
# 2024-10-29 18:53:52,294 - INFO - Round 123: Cand structures reduced from 4010 to 4006
# 2024-10-29 18:53:52,306 - INFO - Round 123: Added structure with min max similarity 0.97053.
# ...
# 2024-10-29 18:59:29,620 - INFO - Ref structures: 2555, Cand structures: 40
# 2024-10-29 18:59:29,621 - INFO - ---------
# 2024-10-29 18:59:29,643 - INFO - Round 1575: Similarity computation completed in 0.02 seconds
# 2024-10-29 18:59:29,644 - INFO - Round 1575: Cand structures reduced from 40 to 39
# 2024-10-29 18:59:29,644 - INFO - Round 1575: Added structure with min max similarity 0.98982.
# 2024-10-29 18:59:29,645 - INFO - Ref structures: 2556, Cand structures: 39
# 2024-10-29 18:59:29,645 - INFO - ---------
# 2024-10-29 18:59:29,667 - INFO - Round 1576: Similarity computation completed in 0.02 seconds
# 2024-10-29 18:59:29,668 - INFO - Round 1576: Cand structures reduced from 39 to 38
# 2024-10-29 18:59:29,669 - INFO - Round 1576: Added structure with min max similarity 0.98983.
# 2024-10-29 18:59:29,669 - INFO - Ref structures: 2557, Cand structures: 38
# 2024-10-29 18:59:29,669 - INFO - ---------
# 2024-10-29 18:59:29,692 - INFO - Round 1577: Similarity computation completed in 0.02 seconds
# 2024-10-29 18:59:29,693 - INFO - Round 1577: Cand structures reduced from 38 to 37
# 2024-10-29 18:59:29,693 - INFO - Round 1577: Added structure with min max similarity 0.98983.
# 2024-10-29 18:59:29,693 - INFO - Ref structures: 2558, Cand structures: 37
# 2024-10-29 18:59:29,694 - INFO - ---------
# 2024-10-29 18:59:29,706 - INFO - Round 1578: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,707 - INFO - Round 1578: Cand structures reduced from 37 to 36
# 2024-10-29 18:59:29,707 - INFO - Round 1578: Added structure with min max similarity 0.98983.
# 2024-10-29 18:59:29,708 - INFO - Ref structures: 2559, Cand structures: 36
# 2024-10-29 18:59:29,708 - INFO - ---------
# 2024-10-29 18:59:29,720 - INFO - Round 1579: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,720 - INFO - Round 1579: Cand structures reduced from 36 to 35
# 2024-10-29 18:59:29,721 - INFO - Round 1579: Added structure with min max similarity 0.98984.
# 2024-10-29 18:59:29,721 - INFO - Ref structures: 2560, Cand structures: 35
# 2024-10-29 18:59:29,722 - INFO - ---------
# 2024-10-29 18:59:29,734 - INFO - Round 1580: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,734 - INFO - Round 1580: Cand structures reduced from 35 to 34
# 2024-10-29 18:59:29,735 - INFO - Round 1580: Added structure with min max similarity 0.98985.
# 2024-10-29 18:59:29,735 - INFO - Ref structures: 2561, Cand structures: 34
# 2024-10-29 18:59:29,736 - INFO - ---------
# 2024-10-29 18:59:29,748 - INFO - Round 1581: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,748 - INFO - Round 1581: Cand structures reduced from 34 to 33
# 2024-10-29 18:59:29,749 - INFO - Round 1581: Added structure with min max similarity 0.98986.
# 2024-10-29 18:59:29,749 - INFO - Ref structures: 2562, Cand structures: 33
# 2024-10-29 18:59:29,749 - INFO - ---------
# 2024-10-29 18:59:29,761 - INFO - Round 1582: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,762 - INFO - Round 1582: Cand structures reduced from 33 to 32
# 2024-10-29 18:59:29,763 - INFO - Round 1582: Added structure with min max similarity 0.98986.
# 2024-10-29 18:59:29,763 - INFO - Ref structures: 2563, Cand structures: 32
# 2024-10-29 18:59:29,763 - INFO - ---------
# 2024-10-29 18:59:29,775 - INFO - Round 1583: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,776 - INFO - Round 1583: Cand structures reduced from 32 to 31
# 2024-10-29 18:59:29,777 - INFO - Round 1583: Added structure with min max similarity 0.98986.
# 2024-10-29 18:59:29,777 - INFO - Ref structures: 2564, Cand structures: 31
# 2024-10-29 18:59:29,777 - INFO - ---------
# 2024-10-29 18:59:29,789 - INFO - Round 1584: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,790 - INFO - Round 1584: Cand structures reduced from 31 to 30
# 2024-10-29 18:59:29,791 - INFO - Round 1584: Added structure with min max similarity 0.98987.
# 2024-10-29 18:59:29,791 - INFO - Ref structures: 2565, Cand structures: 30
# 2024-10-29 18:59:29,791 - INFO - ---------
# 2024-10-29 18:59:29,804 - INFO - Round 1585: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,804 - INFO - Round 1585: Cand structures reduced from 30 to 29
# 2024-10-29 18:59:29,805 - INFO - Round 1585: Added structure with min max similarity 0.98987.
# 2024-10-29 18:59:29,805 - INFO - Ref structures: 2566, Cand structures: 29
# 2024-10-29 18:59:29,805 - INFO - ---------
# 2024-10-29 18:59:29,817 - INFO - Round 1586: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,818 - INFO - Round 1586: Cand structures reduced from 29 to 28
# 2024-10-29 18:59:29,819 - INFO - Round 1586: Added structure with min max similarity 0.98987.
# 2024-10-29 18:59:29,819 - INFO - Ref structures: 2567, Cand structures: 28
# 2024-10-29 18:59:29,819 - INFO - ---------
# 2024-10-29 18:59:29,831 - INFO - Round 1587: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,832 - INFO - Round 1587: Cand structures reduced from 28 to 27
# 2024-10-29 18:59:29,832 - INFO - Round 1587: Added structure with min max similarity 0.98988.
# 2024-10-29 18:59:29,833 - INFO - Ref structures: 2568, Cand structures: 27
# 2024-10-29 18:59:29,833 - INFO - ---------
# 2024-10-29 18:59:29,845 - INFO - Round 1588: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,846 - INFO - Round 1588: Cand structures reduced from 27 to 26
# 2024-10-29 18:59:29,846 - INFO - Round 1588: Added structure with min max similarity 0.98988.
# 2024-10-29 18:59:29,846 - INFO - Ref structures: 2569, Cand structures: 26
# 2024-10-29 18:59:29,847 - INFO - ---------
# 2024-10-29 18:59:29,858 - INFO - Round 1589: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,859 - INFO - Round 1589: Cand structures reduced from 26 to 25
# 2024-10-29 18:59:29,860 - INFO - Round 1589: Added structure with min max similarity 0.9899.
# 2024-10-29 18:59:29,860 - INFO - Ref structures: 2570, Cand structures: 25
# 2024-10-29 18:59:29,860 - INFO - ---------
# 2024-10-29 18:59:29,872 - INFO - Round 1590: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,872 - INFO - Round 1590: Cand structures reduced from 25 to 24
# 2024-10-29 18:59:29,873 - INFO - Round 1590: Added structure with min max similarity 0.9899.
# 2024-10-29 18:59:29,873 - INFO - Ref structures: 2571, Cand structures: 24
# 2024-10-29 18:59:29,873 - INFO - ---------
# 2024-10-29 18:59:29,885 - INFO - Round 1591: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,886 - INFO - Round 1591: Cand structures reduced from 24 to 23
# 2024-10-29 18:59:29,886 - INFO - Round 1591: Added structure with min max similarity 0.9899.
# 2024-10-29 18:59:29,887 - INFO - Ref structures: 2572, Cand structures: 23
# 2024-10-29 18:59:29,887 - INFO - ---------
# 2024-10-29 18:59:29,898 - INFO - Round 1592: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,899 - INFO - Round 1592: Cand structures reduced from 23 to 22
# 2024-10-29 18:59:29,900 - INFO - Round 1592: Added structure with min max similarity 0.9899.
# 2024-10-29 18:59:29,900 - INFO - Ref structures: 2573, Cand structures: 22
# 2024-10-29 18:59:29,900 - INFO - ---------
# 2024-10-29 18:59:29,912 - INFO - Round 1593: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,913 - INFO - Round 1593: Cand structures reduced from 22 to 21
# 2024-10-29 18:59:29,913 - INFO - Round 1593: Added structure with min max similarity 0.9899.
# 2024-10-29 18:59:29,913 - INFO - Ref structures: 2574, Cand structures: 21
# 2024-10-29 18:59:29,914 - INFO - ---------
# 2024-10-29 18:59:29,926 - INFO - Round 1594: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,927 - INFO - Round 1594: Cand structures reduced from 21 to 20
# 2024-10-29 18:59:29,927 - INFO - Round 1594: Added structure with min max similarity 0.98991.
# 2024-10-29 18:59:29,927 - INFO - Ref structures: 2575, Cand structures: 20
# 2024-10-29 18:59:29,928 - INFO - ---------
# 2024-10-29 18:59:29,939 - INFO - Round 1595: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,940 - INFO - Round 1595: Cand structures reduced from 20 to 19
# 2024-10-29 18:59:29,940 - INFO - Round 1595: Added structure with min max similarity 0.98991.
# 2024-10-29 18:59:29,941 - INFO - Ref structures: 2576, Cand structures: 19
# 2024-10-29 18:59:29,941 - INFO - ---------
# 2024-10-29 18:59:29,953 - INFO - Round 1596: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,954 - INFO - Round 1596: Cand structures reduced from 19 to 18
# 2024-10-29 18:59:29,954 - INFO - Round 1596: Added structure with min max similarity 0.98992.
# 2024-10-29 18:59:29,954 - INFO - Ref structures: 2577, Cand structures: 18
# 2024-10-29 18:59:29,955 - INFO - ---------
# 2024-10-29 18:59:29,966 - INFO - Round 1597: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,967 - INFO - Round 1597: Cand structures reduced from 18 to 17
# 2024-10-29 18:59:29,967 - INFO - Round 1597: Added structure with min max similarity 0.98993.
# 2024-10-29 18:59:29,967 - INFO - Ref structures: 2578, Cand structures: 17
# 2024-10-29 18:59:29,968 - INFO - ---------
# 2024-10-29 18:59:29,979 - INFO - Round 1598: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,980 - INFO - Round 1598: Cand structures reduced from 17 to 16
# 2024-10-29 18:59:29,980 - INFO - Round 1598: Added structure with min max similarity 0.98993.
# 2024-10-29 18:59:29,981 - INFO - Ref structures: 2579, Cand structures: 16
# 2024-10-29 18:59:29,981 - INFO - ---------
# 2024-10-29 18:59:29,992 - INFO - Round 1599: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:29,993 - INFO - Round 1599: Cand structures reduced from 16 to 15
# 2024-10-29 18:59:29,993 - INFO - Round 1599: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:29,993 - INFO - Ref structures: 2580, Cand structures: 15
# 2024-10-29 18:59:29,994 - INFO - ---------
# 2024-10-29 18:59:30,005 - INFO - Round 1600: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,006 - INFO - Round 1600: Cand structures reduced from 15 to 14
# 2024-10-29 18:59:30,006 - INFO - Round 1600: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:30,006 - INFO - Ref structures: 2581, Cand structures: 14
# 2024-10-29 18:59:30,007 - INFO - ---------
# 2024-10-29 18:59:30,018 - INFO - Round 1601: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,019 - INFO - Round 1601: Cand structures reduced from 14 to 13
# 2024-10-29 18:59:30,019 - INFO - Round 1601: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:30,020 - INFO - Ref structures: 2582, Cand structures: 13
# 2024-10-29 18:59:30,020 - INFO - ---------
# 2024-10-29 18:59:30,032 - INFO - Round 1602: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,033 - INFO - Round 1602: Cand structures reduced from 13 to 12
# 2024-10-29 18:59:30,033 - INFO - Round 1602: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:30,033 - INFO - Ref structures: 2583, Cand structures: 12
# 2024-10-29 18:59:30,034 - INFO - ---------
# 2024-10-29 18:59:30,045 - INFO - Round 1603: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,046 - INFO - Round 1603: Cand structures reduced from 12 to 11
# 2024-10-29 18:59:30,046 - INFO - Round 1603: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:30,047 - INFO - Ref structures: 2584, Cand structures: 11
# 2024-10-29 18:59:30,047 - INFO - ---------
# 2024-10-29 18:59:30,059 - INFO - Round 1604: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,059 - INFO - Round 1604: Cand structures reduced from 11 to 10
# 2024-10-29 18:59:30,060 - INFO - Round 1604: Added structure with min max similarity 0.98994.
# 2024-10-29 18:59:30,060 - INFO - Ref structures: 2585, Cand structures: 10
# 2024-10-29 18:59:30,060 - INFO - ---------
# 2024-10-29 18:59:30,072 - INFO - Round 1605: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,073 - INFO - Round 1605: Cand structures reduced from 10 to 9
# 2024-10-29 18:59:30,073 - INFO - Round 1605: Added structure with min max similarity 0.98995.
# 2024-10-29 18:59:30,073 - INFO - Ref structures: 2586, Cand structures: 9
# 2024-10-29 18:59:30,074 - INFO - ---------
# 2024-10-29 18:59:30,085 - INFO - Round 1606: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,085 - INFO - Round 1606: Cand structures reduced from 9 to 8
# 2024-10-29 18:59:30,086 - INFO - Round 1606: Added structure with min max similarity 0.98995.
# 2024-10-29 18:59:30,086 - INFO - Ref structures: 2587, Cand structures: 8
# 2024-10-29 18:59:30,086 - INFO - ---------
# 2024-10-29 18:59:30,098 - INFO - Round 1607: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,099 - INFO - Round 1607: Cand structures reduced from 8 to 7
# 2024-10-29 18:59:30,099 - INFO - Round 1607: Added structure with min max similarity 0.98996.
# 2024-10-29 18:59:30,099 - INFO - Ref structures: 2588, Cand structures: 7
# 2024-10-29 18:59:30,100 - INFO - ---------
# 2024-10-29 18:59:30,111 - INFO - Round 1608: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,112 - INFO - Round 1608: Cand structures reduced from 7 to 6
# 2024-10-29 18:59:30,112 - INFO - Round 1608: Added structure with min max similarity 0.98997.
# 2024-10-29 18:59:30,112 - INFO - Ref structures: 2589, Cand structures: 6
# 2024-10-29 18:59:30,113 - INFO - ---------
# 2024-10-29 18:59:30,124 - INFO - Round 1609: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,125 - INFO - Round 1609: Cand structures reduced from 6 to 5
# 2024-10-29 18:59:30,125 - INFO - Round 1609: Added structure with min max similarity 0.98997.
# 2024-10-29 18:59:30,125 - INFO - Ref structures: 2590, Cand structures: 5
# 2024-10-29 18:59:30,126 - INFO - ---------
# 2024-10-29 18:59:30,137 - INFO - Round 1610: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,138 - INFO - Round 1610: Cand structures reduced from 5 to 4
# 2024-10-29 18:59:30,138 - INFO - Round 1610: Added structure with min max similarity 0.98998.
# 2024-10-29 18:59:30,138 - INFO - Ref structures: 2591, Cand structures: 4
# 2024-10-29 18:59:30,139 - INFO - ---------
# 2024-10-29 18:59:30,150 - INFO - Round 1611: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,151 - INFO - Round 1611: Cand structures reduced from 4 to 3
# 2024-10-29 18:59:30,151 - INFO - Round 1611: Added structure with min max similarity 0.98999.
# 2024-10-29 18:59:30,151 - INFO - Ref structures: 2592, Cand structures: 3
# 2024-10-29 18:59:30,151 - INFO - ---------
# 2024-10-29 18:59:30,163 - INFO - Round 1612: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,164 - INFO - Round 1612: Cand structures reduced from 3 to 2
# 2024-10-29 18:59:30,164 - INFO - Round 1612: Added structure with min max similarity 0.98999.
# 2024-10-29 18:59:30,164 - INFO - Ref structures: 2593, Cand structures: 2
# 2024-10-29 18:59:30,165 - INFO - ---------
# 2024-10-29 18:59:30,176 - INFO - Round 1613: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,177 - INFO - Round 1613: Cand structures reduced from 2 to 1
# 2024-10-29 18:59:30,177 - INFO - Round 1613: Added structure with min max similarity 0.98999.
# 2024-10-29 18:59:30,177 - INFO - Ref structures: 2594, Cand structures: 1
# 2024-10-29 18:59:30,177 - INFO - ---------
# 2024-10-29 18:59:30,189 - INFO - Round 1614: Similarity computation completed in 0.01 seconds
# 2024-10-29 18:59:30,189 - INFO - Round 1614: Cand structures reduced from 1 to 0
# 2024-10-29 18:59:30,190 - INFO - No structures remaining in candidate list.
# 2024-10-29 18:59:30,190 - INFO - Ref structures: 2594, Cand structures: 0
# 2024-10-29 18:59:30,190 - INFO - ---------
# 2024-10-29 18:59:30,350 - INFO - SOAP descriptors saved to 'updated_ref_soap_descriptors.h5'
# 2024-10-29 18:59:30,690 - INFO - Updated reference structures saved to 'updated_ref_structures.xyz'
# 2024-10-29 18:59:30,690 - INFO - Done! Total time elapsed: 794.04 seconds
# 2024-10-29 18:59:30,691 - INFO - Log end

# %%
soap_data = read_soap_from_hdf5("updated_ref_soap_descriptors.h5")
defaultdict_profiler(soap_data)
# Out:
# Available formulas: ['C2H3N3O', 'C3H8O2', 'C6H10', 'CHN3O']
# Formula: C2H3N3O, Shape of SOAP descriptors: (682, 9, 312)
# Formula: C3H8O2, Shape of SOAP descriptors: (1567, 13, 312)
# Formula: C6H10, Shape of SOAP descriptors: (206, 16, 312)
# Formula: CHN3O, Shape of SOAP descriptors: (139, 6, 312)
# ---------
